# %%
import numpy as np
import time
from scipy.fft import fft
import cv2
import os
from tensorflow import keras
from google.colab import files
import pickle
print(keras.__version__)
# Out:
# 2.4.0

# %%
from IPython.display import clear_output

# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Knot_Tying.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Needle_Passing.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Suturing.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Experimental_setup.zip

clear_output()

# %%
# !unzip -o Knot_Tying.zip -d JIGSAWS
# !unzip -o Needle_Passing.zip -d JIGSAWS
# !unzip -o Suturing.zip -d JIGSAWS
# !unzip -o Experimental_setup.zip -d JIGSAWS

clear_output()

# %%
from keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
ResNetModel = ResNet50(weights='imagenet')
# ResNetModel.summary()

# Build a new model that is ResNet50 minus the very last layer
last_layer = ResNetModel.get_layer("avg_pool")
ResNet2048 = keras.Model(inputs=ResNetModel.inputs, outputs=last_layer.output)
# ResNet2048.summary()
# Out:
# ...
# 102973440/102967424 [==============================] - 1s 0us/step

# %%
def video2Matix(videoData, root):
  cap=cv2.VideoCapture(root)
  rawPrediction = []
  l = videoLength(root)
  for i in range(l):
  # while True:
    ret, frame=cap.read()
    if ret == False:
      break
    x = cv2.resize(frame, (224,224), interpolation = cv2.INTER_AREA)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = ResNet2048.predict(x)
    rawPrediction.append(preds)

  rawPrediction = np.asarray(rawPrediction)

  fftData = []
  ResNetFFT(rawPrediction, fftData, fMax)

  videoData.append(fftData)
  return videoData

# %%
def videoLength(root):
  cap=cv2.VideoCapture(root)
  i = 0
  while True:
    ret, frame=cap.read()
    if ret == False:
      break
    i = i + 1
  return i

# %%
def ResNetFFT(rawPrediction, fftData, fMax):
  for attribute in range(2048):
    temp = []
    for i in range(len(rawPrediction)):
      temp.append(rawPrediction[i, 0, attribute])
    temp = np.asarray(temp)
    yf = fft(temp)
    OUT = np.abs(yf)
    fftData.append(OUT[:fMax])
  fftData = np.asarray(fftData)
  return fftData

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 212.60995411872864 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 809.407910823822 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 755.9065675735474 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 744.1447002887726 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 750.1438729763031 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 751.395781993866 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 671.4589807987213 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_B004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 666.3306682109833 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 997.962075471878 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 990.941201210022 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 185.62181448936462 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 175.83731055259705 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 174.85460305213928 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 175.1418972015381 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 120.00389742851257 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 117.61515402793884 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 123.27541208267212 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_C005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 121.3425440788269 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 236.491361618042 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 222.06872630119324 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 155.26580142974854 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 156.17563891410828 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 153.2615966796875 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 153.5061285495758 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 128.08927035331726 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 159.5834949016571 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 100.47100400924683 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_D005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 100.6315929889679 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 154.97848796844482 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 154.6573886871338 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 97.65676593780518 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 100.61156439781189 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 162.18098974227905 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 162.140451669693 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 160.69716215133667 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 159.62219285964966 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 157.28238821029663 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_E005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 157.31360626220703 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 95.70743918418884 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 92.34360265731812 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 74.98866176605225 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 74.08505868911743 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 108.29472827911377 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 113.55418920516968 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 82.81152391433716 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 86.10382008552551 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 98.07283997535706 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_F005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 99.84382438659668 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_G004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 281.32163763046265 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_G005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 123.86806011199951 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 408.85293436050415 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 417.9908444881439 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 168.94839024543762 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 184.6128535270691 seconds ---

# %%
videoData = []
yHotV = []
yV = []
# fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 174.31272268295288 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 174.21293950080872 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 150.97113370895386 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_H005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 158.0911147594452 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 162.95754766464233 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 155.44010615348816 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 215.643723487854 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 228.2434947490692 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 191.6954894065857 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 189.6207001209259 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 163.1512303352356 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Needle_Passing/video/Needle_Passing_I005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[38:66], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[38:66])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 162.81822633743286 seconds ---
