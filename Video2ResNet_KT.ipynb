# %%
import numpy as np
import time
from scipy.fft import fft
import cv2
import os
from tensorflow import keras
from google.colab import files
import pickle
print(keras.__version__)
# Out:
# 2.4.0

# %%
from IPython.display import clear_output

# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Knot_Tying.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Needle_Passing.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Suturing.zip
# !wget https://cs.jhu.edu/~los/jigsaws/dwnld/DAqBjdiRPB8xXnYpsplWSmqmg96JKe6x/Experimental_setup.zip

clear_output()

# %%
# !unzip -o Knot_Tying.zip -d JIGSAWS
# !unzip -o Needle_Passing.zip -d JIGSAWS
# !unzip -o Suturing.zip -d JIGSAWS
# !unzip -o Experimental_setup.zip -d JIGSAWS

clear_output()

# %%
from keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
ResNetModel = ResNet50(weights='imagenet')
# ResNetModel.summary()

# Build a new model that is ResNet50 minus the very last layer
last_layer = ResNetModel.get_layer("avg_pool")
ResNet2048 = keras.Model(inputs=ResNetModel.inputs, outputs=last_layer.output)
# ResNet2048.summary()
# Out:
# ...
# 102973440/102967424 [==============================] - 1s 0us/step

# %%
def video2Matix(videoData, root):
  cap=cv2.VideoCapture(root)
  rawPrediction = []
  l = videoLength(root)
  for i in range(l):
  # while True:
    ret, frame=cap.read()
    if ret == False:
      break
    x = cv2.resize(frame, (224,224), interpolation = cv2.INTER_AREA)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = ResNet2048.predict(x)
    rawPrediction.append(preds)
  # cv2_imshow(frame)
  rawPrediction = np.asarray(rawPrediction)

  fftData = []
  ResNetFFT(rawPrediction, fftData, fMax)

  videoData.append(fftData)
  return videoData

# %%
def videoLength(root):
  cap=cv2.VideoCapture(root)
  i = 0
  while True:
    ret, frame=cap.read()
    if ret == False:
      break
    i = i + 1
  return i

# %%
def ResNetFFT(rawPrediction, fftData, fMax):
  for attribute in range(2048):
    temp = []
    for i in range(len(rawPrediction)):
      temp.append(rawPrediction[i, 0, attribute])
    temp = np.asarray(temp)
    yf = fft(temp)
    # OUT = 2.0/N * np.abs(yf)
    OUT = np.abs(yf)
    fftData.append(OUT[:fMax])
  fftData = np.asarray(fftData)
  return fftData

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 115.01973748207092 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 88.54088115692139 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 75.66331553459167 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 74.7689778804779 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 81.94102931022644 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 81.80294251441956 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 92.67129611968994 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_B004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 91.54261136054993 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 61.77845358848572 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 62.66133141517639 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 54.10565257072449 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 53.61205053329468 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 54.012075901031494 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 53.716800689697266 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 70.27581214904785 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 70.48613810539246 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 58.15324831008911 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_C005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 57.68457508087158 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 71.28727173805237 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 70.0832748413086 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 62.44281244277954 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 62.006120920181274 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 70.85990333557129 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 70.56342124938965 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 52.59831190109253 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 53.064939737319946 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 63.337788581848145 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_D005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 63.87044048309326 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 80.79538011550903 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 80.24286413192749 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 64.74070644378662 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 65.02038502693176 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 71.37663722038269 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 70.59348845481873 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 69.75403356552124 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 73.71530723571777 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 60.324707984924316 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_E005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 60.119107723236084 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 44.585835695266724 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 43.93089199066162 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 48.64576697349548 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 48.564286947250366 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 129.97534918785095 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 130.69316244125366 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 83.38314938545227 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 86.98957705497742 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 62.968788623809814 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_F005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 65.7802312374115 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 108.11025381088257 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 113.50169110298157 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 104.37343406677246 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 109.68268203735352 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 115.31359529495239 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 120.09105205535889 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 175.46757292747498 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 191.0078673362732 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 76.56840252876282 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_G005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 84.08622860908508 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_H003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 300)
# --- 77.76375579833984 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_H003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 77.95186591148376 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_H004_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 108.55606150627136 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_H004_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 108.26683449745178 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_H005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 95.06987190246582 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_H005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 94.94693732261658 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I001_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 112.2540328502655 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I001_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 111.31945776939392 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I002_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 115.73877167701721 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I002_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 117.69663572311401 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I003_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 101.37938141822815 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I003_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 101.93819499015808 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I005_capture1.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 128.85725617408752 seconds ---

# %%
videoData = []
yHotV = []
yV = []
fMax = 300

root = '/content/JIGSAWS/Knot_Tying/video/Knot_Tying_I005_capture2.avi'
start_time = time.time()
videoData = video2Matix(videoData, root)

videoData = np.asarray(videoData)
print(videoData.shape)
with open(root[34:58], 'wb') as f:
    pickle.dump(videoData, f)
files.download(root[34:58])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (1, 2048, 800)
# --- 128.24406385421753 seconds ---
